# %% [markdown]
# Импортируем библиотеки и подключаем набор данных

# %%
import random
import pandas as pd
pd.options.mode.chained_assignment = None
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

df = pd.read_csv('pokemon.csv')

# %% [markdown]
# **Выполняем преобработку данных**

# %% [markdown]
# Добавим пропуски в значениях

# %%
columns = df.columns
for column in columns:
    rows = np.random.randint(0, len(df) - 1, random.randint(1, 10))
    for row in rows:
        df[column][row] = np.nan
df.isnull().sum()
# Out:
# number          9
# name            3
# type1           6
# type2         501
# total           6
# hp              6
# attack          5
# defense         8
# sp_attack       1
# sp_defense      5
# speed           2
# generation      6
# legendary       4
# dtype: int64

# %% [markdown]
# Числовые переменные помечаем меткой float64, категориальные переменные помечаем меткой category и выводим набор данных

# %%
df[['number', 'total', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed', 'generation']] = \
df[['number', 'total', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed', 'generation']].astype('float64')
df[['name', 'type1', 'type2']] = df[['name', 'type1', 'type2']].astype('category')
df['legendary'] = df['legendary'].astype('bool')
df.tail()
# Out:
#       number                  name    type1  type2  total     hp  attack  \
# 1067   896.0             Glastrier      Ice    NaN  580.0  100.0   145.0
# 1068   897.0             Spectrier    Ghost    NaN  580.0  100.0    65.0
# 1069   898.0               Calyrex  Psychic  Grass  500.0  100.0    80.0
# 1070   898.0     Ice Rider Calyrex  Psychic    Ice  680.0  100.0   165.0
# 1071   898.0  Shadow Rider Calyrex  Psychic  Ghost  680.0  100.0    85.0
#
#       defense  sp_attack  sp_defense  speed  generation  legendary
# 1067    130.0       65.0       110.0   30.0         8.0       True
# 1068     60.0      145.0        80.0  130.0         8.0       True
# 1069     80.0       80.0        80.0   80.0         8.0       True
# 1070    150.0       85.0       130.0   50.0         8.0       True
# 1071     80.0      165.0       100.0  150.0         8.0       True

# %%
df.head()
# Out:
#    number                 name  type1   type2  total    hp  attack  defense  \
# 0     1.0            Bulbasaur  Grass  Poison  318.0  45.0    49.0     49.0
# 1     2.0              Ivysaur  Grass  Poison  405.0  60.0    62.0     63.0
# 2     3.0             Venusaur  Grass  Poison  525.0  80.0    82.0     83.0
# 3     3.0        Mega Venusaur  Grass  Poison  625.0  80.0   100.0    123.0
# 4     3.0  Gigantamax Venusaur  Grass  Poison  525.0  80.0    82.0     83.0
#
#    sp_attack  sp_defense  speed  generation  legendary
# 0       65.0        65.0   45.0         1.0      False
# 1       80.0        80.0   60.0         1.0      False
# 2        NaN       100.0   80.0         1.0      False
# 3      122.0       120.0   80.0         1.0      False
# 4      100.0       100.0   80.0         1.0      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   number      1063 non-null   float64
#  1   name        1069 non-null   category
#  2   type1       1066 non-null   category
#  3   type2       571 non-null    category
#  4   total       1066 non-null   float64
#  5   hp          1066 non-null   float64
#  6   attack      1067 non-null   float64
#  7   defense     1064 non-null   float64
#  8   sp_attack   1071 non-null   float64
#  9   sp_defense  1067 non-null   float64
#  10  speed       1070 non-null   float64
#  11  generation  1066 non-null   float64
#  12  legendary   1072 non-null   bool
# dtypes: bool(1), category(3), float64(9)
# memory usage: 122.8 KB

# %%
df.describe(include='all')
# Out:
#              number       name  type1   type2        total           hp  \
# count   1063.000000       1069   1066     571  1066.000000  1066.000000
# unique          NaN       1069     20      18          NaN          NaN
# top             NaN  Abomasnow  Water  Flying          NaN          NaN
# freq            NaN          1    135     112          NaN          NaN
# mean     445.242709        NaN    NaN     NaN   440.915572    70.403377
# std      268.350828        NaN    NaN     NaN   121.634110    26.760502
# min        1.000000        NaN    NaN     NaN   175.000000     1.000000
# 25%      209.500000        NaN    NaN     NaN   330.000000    50.000000
# 50%      441.000000        NaN    NaN     NaN   461.500000    68.000000
# 75%      683.500000        NaN    NaN     NaN   519.750000    83.750000
# max      898.000000        NaN    NaN     NaN  1125.000000   255.000000
#
#              attack      defense    sp_attack   sp_defense        speed  \
# count   1067.000000  1064.000000  1071.000000  1067.000000  1070.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      80.996251    75.012218    73.248366    72.548266    68.800000
# std       32.515316    31.292581    32.648137    27.955276    30.084527
# min        5.000000     5.000000    10.000000    20.000000     5.000000
# 25%       56.000000    51.750000    50.000000    50.000000    45.000000
# 50%       80.000000    70.000000    65.000000    70.000000    65.000000
# 75%      100.000000    90.250000    95.000000    90.000000    90.000000
# max      190.000000   250.000000   194.000000   250.000000   200.000000
#
#          generation legendary
# count   1066.000000      1072
# unique          NaN         2
# top             NaN     False
# freq            NaN       950
# mean       4.299250       NaN
# std        2.348017       NaN
# min        0.000000       NaN
# 25%        2.000000       NaN
# 50%        4.000000       NaN
# 75%        6.000000       NaN
# max        8.000000       NaN

# %% [markdown]
# **Выполним поиск признаков, содержащих пропуски, и выведем основные статистические показатели**

# %%
for column in df.columns:
    if (df[column].isnull().sum() > 0):
        print('Column\t', column)
        print('NaNs\t', df[column].isnull().sum())
        print(df[column].describe(include='all'))
        print('-----------------------------')
# Out:
# Column	 number
# NaNs	 9
# count    1063.000000
# mean      445.242709
# std       268.350828
# min         1.000000
# 25%       209.500000
# 50%       441.000000
# 75%       683.500000
# max       898.000000
# Name: number, dtype: float64
# -----------------------------
# Column	 name
# NaNs	 3
# count          1069
# unique         1069
# top       Abomasnow
# freq              1
# Name: name, dtype: object
# -----------------------------
# Column	 type1
# NaNs	 6
# count      1066
# unique       20
# top       Water
# freq        135
# Name: type1, dtype: object
# -----------------------------
# Column	 type2
# NaNs	 501
# count        571
# unique        18
# top       Flying
# freq         112
# Name: type2, dtype: object
# -----------------------------
# Column	 total
# NaNs	 6
# count    1066.000000
# mean      440.915572
# std       121.634110
# min       175.000000
# 25%       330.000000
# 50%       461.500000
# 75%       519.750000
# max      1125.000000
# Name: total, dtype: float64
# -----------------------------
# Column	 hp
# NaNs	 6
# count    1066.000000
# mean       70.403377
# std        26.760502
# min         1.000000
# 25%        50.000000
# 50%        68.000000
# 75%        83.750000
# max       255.000000
# Name: hp, dtype: float64
# -----------------------------
# Column	 attack
# NaNs	 5
# count    1067.000000
# mean       80.996251
# std        32.515316
# min         5.000000
# 25%        56.000000
# 50%        80.000000
# 75%       100.000000
# max       190.000000
# Name: attack, dtype: float64
# -----------------------------
# Column	 defense
# NaNs	 8
# count    1064.000000
# mean       75.012218
# std        31.292581
# min         5.000000
# 25%        51.750000
# 50%        70.000000
# 75%        90.250000
# max       250.000000
# Name: defense, dtype: float64
# -----------------------------
# Column	 sp_attack
# NaNs	 1
# count    1071.000000
# mean       73.248366
# std        32.648137
# min        10.000000
# 25%        50.000000
# 50%        65.000000
# 75%        95.000000
# max       194.000000
# Name: sp_attack, dtype: float64
# -----------------------------
# Column	 sp_defense
# NaNs	 5
# count    1067.000000
# mean       72.548266
# std        27.955276
# min        20.000000
# 25%        50.000000
# 50%        70.000000
# 75%        90.000000
# max       250.000000
# Name: sp_defense, dtype: float64
# -----------------------------
# Column	 speed
# NaNs	 2
# count    1070.000000
# mean       68.800000
# std        30.084527
# min         5.000000
# 25%        45.000000
# 50%        65.000000
# 75%        90.000000
# max       200.000000
# Name: speed, dtype: float64
# -----------------------------
# Column	 generation
# NaNs	 6
# count    1066.000000
# mean        4.299250
# std         2.348017
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max         8.000000
# Name: generation, dtype: float64
# -----------------------------

# %% [markdown]
# **Применим методы восстановления значения признака**

# %% [markdown]
# Применим метод замены пропусков для числовых значений: среднее, медиана, на основе корреляции, на основе расстояния

# %% [markdown]
# Среднее

# %%
float_df = df.select_dtypes(include=['float64'])

for column in float_df.columns:
    if (float_df[column].isnull().sum() > 0):
        float_df[column] = float_df[column].fillna(float_df[column].mean())
        print('Среднее значение для', column, ":", float_df[column].mean())
        print('------------------------------------------------------')
# Out:
# Среднее значение для number : 445.24270931326436
# ------------------------------------------------------
# Среднее значение для total : 440.9155722326454
# ------------------------------------------------------
# Среднее значение для hp : 70.4033771106942
# ------------------------------------------------------
# Среднее значение для attack : 80.9962511715089
# ------------------------------------------------------
# Среднее значение для defense : 75.01221804511279
# ------------------------------------------------------
# Среднее значение для sp_attack : 73.24836601307189
# ------------------------------------------------------
# Среднее значение для sp_defense : 72.54826616682286
# ------------------------------------------------------
# Среднее значение для speed : 68.80000000000001
# ------------------------------------------------------
# Среднее значение для generation : 4.299249530956848
# ------------------------------------------------------

# %% [markdown]
# Медиана

# %%
float_df = df.select_dtypes(include=['float64'])

for column in float_df.columns:
    if (float_df[column].isnull().sum() > 0):
        float_df[column] = float_df[column].fillna(float_df[column].median())
        print('Медианное значение для', column, ":", float_df[column].median())
        print('------------------------------------------------------')
# Out:
# Медианное значение для number : 441.0
# ------------------------------------------------------
# Медианное значение для total : 461.5
# ------------------------------------------------------
# Медианное значение для hp : 68.0
# ------------------------------------------------------
# Медианное значение для attack : 80.0
# ------------------------------------------------------
# Медианное значение для defense : 70.0
# ------------------------------------------------------
# Медианное значение для sp_attack : 65.0
# ------------------------------------------------------
# Медианное значение для sp_defense : 70.0
# ------------------------------------------------------
# Медианное значение для speed : 65.0
# ------------------------------------------------------
# Медианное значение для generation : 4.0
# ------------------------------------------------------

# %% [markdown]
# На основе корреляции (замена пустых значений колонки total на основе колонок hp, attack и defense)

# %%
float_df = df.select_dtypes(include=['float64'])

# for column in float_df.columns:
#     if (float_df[column].isnull().sum() > 0):
#         float_df[column] = float_df[column].fillna(float_df[column].corr(df['total'])*float_df[column].median())
#         print('Коэффициент корреляции', column, "по отношению к total :", float_df[column].corr(df['total']))
#         print('Корреляционное значение', column, ":", float_df[column].corr(df['total'])*float_df[column].median())
#         print('-----------------------------------------------------------------------------')

index_total = float_df.index[float_df.total.apply(pd.isna)][0]
mean_total, mean_hp, mean_attack, mean_defense = float_df.dropna().total.mean(), float_df.dropna().hp.mean(), float_df.dropna().attack.mean(), float_df.dropna().defense.mean()
hp_corr, attack_corr, defense_corr = float_df.corr()['total'].iloc[2], float_df.corr()['total'].iloc[3], float_df.corr()['total'].iloc[4]

print()
print(f'mean total: {mean_total}, mean hp: {mean_hp}, mean defense: {mean_defense}')
print(f'hp_corr: {round(hp_corr, 2)}, attack corr: {round(attack_corr, 2)}, defense corr: {round(defense_corr, 2)}')

numerator = hp_corr * (float_df.hp.iloc[index_total] - mean_hp) + attack_corr * (float_df.attack.iloc[index_total] - mean_attack) + defense_corr * (float_df.defense.iloc[index_total] - mean_defense)
denominator = abs(hp_corr) + abs(attack_corr) + abs(defense_corr)

empty_total = mean_total + (numerator / denominator)

float_df.total.at[index_total] = empty_total
print()
print("Полученное значение на основе корреляции:", empty_total)
# Out:
# mean total: 441.61853658536586, mean hp: 70.19707317073171, mean defense: 75.22829268292683
# hp_corr: 0.66, attack corr: 0.73, defense corr: 0.63
#
# Полученное значение на основе корреляции: 457.92068150388025

# %% [markdown]
# На основе расстояний

# %%
import math

def calc_metric(sample1: np.array, sample2: np.array, formula: str) -> float:

    fn = {
        'euclid': lambda : np.sqrt(np.sum(np.square(sample1 - sample2))),
        'manhattan': lambda : np.sum(np.abs(sample1 - sample2)),
        'max': lambda : np.max(np.abs(sample1 - sample2))
    }

        
    return fn[formula]()

float_df = df.select_dtypes(include=['float64'])

metrics_result = []

df_test = float_df.drop(columns = ['number', 'total', 'sp_attack', 'sp_defense', 'speed', 'generation'])
df_test.dropna()

x = df_test.loc[float_df.total.isnull()].to_numpy()

for columns, values in df_test[~float_df.total.isnull()].iterrows():
    x2 = values.to_numpy()
    metric_value = calc_metric(x, x2, 'euclid')
    metrics_result.append(metric_value)
    print('metric:', metric_value)

values = float_df[~float_df.total.isnull()].total.to_numpy()
metrics_result = np.array(metrics_result)

normal = 1 / np.sum(1 / metrics_result)

score = np.sum(np.divide(values, metrics_result)) * normal

print('Результат на основе расстояний:', score)
# Out:
# metric: 231.84477565819765
# metric: 194.0463862070098
# metric: 164.60255162056268
# metric: 180.94750620000266
# metric: 164.60255162056268
# metric: 244.20892694576094
# metric: 200.48441335924346
# metric: 168.6238417306402
# metric: 209.86185932655795
# metric: 180.75950874020432
# metric: 168.6238417306402
# metric: 216.1712284278368
# metric: 180.05554698481245
# metric: 161.05899540230592
# metric: 181.27327436773464
# metric: 161.05899540230592
# metric: 267.45093007877165
# metric: 250.53941805632104
# metric: 220.81666603768838
# metric: 220.81666603768838
# metric: 274.5177589883758
# metric: 253.96850198400588
# metric: 221.33684736166276
# metric: 283.60183356247893
# metric: 251.91268328530026
# metric: 202.26220605936246
# metric: 169.32217811025228
# metric: 165.6804152578089
# metric: 263.91286440793294
# metric: 263.91286440793294
# metric: 198.7460691435179
# metric: nan
# metric: 258.28279075463
# metric: 188.12230064508566
# metric: 243.57750306627253
# metric: 185.9569842732453
# metric: 251.2767398706056
# metric: 251.2767398706056
# metric: 203.15019074566482
# metric: 208.13457185196313
# metric: 183.63006289820848
# metric: 181.93405398660252
# metric: 173.98275776639477
# metric: 179.8054504179448
# metric: 220.33610689126738
# metric: 183.57015007892758
# metric: 166.667333332
# metric: 238.3275057562597
# metric: 197.3980749652843
# metric: 179.12565422071737
# metric: 218.06421072702418
# metric: 173.2108541633578
# metric: 257.2158626523644
# metric: 257.2158626523644
# metric: 171.49344010777787
# metric: 173.00867030296487
# metric: 270.44407924744814
# metric: 246.35340468522045
# metric: 258.9980694908748
# metric: 175.35677916750183
# metric: 223.8972978845435
# metric: 185.903200617956
# metric: 164.59040069214242
# metric: 227.13432149281184
# metric: 182.04395073717774
# metric: 213.5415650406262
# metric: 190.0526242912736
# metric: 305.9411708155671
# metric: 298.9648808806814
# metric: 232.70152556440192
# metric: 228.67006800191405
# metric: 258.9980694908748
# metric: 258.9980694908748
# metric: 267.28262195660983
# metric: 210.95023109728987
# metric: 191.38965489283896
# metric: 194.91023574969068
# metric: 226.21671025810627
# metric: 167.73192898193236
# metric: 247.52777621915484
# metric: 203.2732151563506
# metric: 218.56349191939628
# metric: 185.22958726942088
# metric: 248.4552273549502
# metric: 187.18974330876145
# metric: 166.55329477377504
# metric: 327.3071951546437
# metric: 274.5177589883758
# metric: 227.35434897973693
# metric: 203.49447166937975
# metric: 201.41995928904365
# metric: 183.27574853209575
# metric: 211.63648078722156
# metric: 211.63648078722156
# metric: 237.5289456045305
# metric: 206.51876428063383
# metric: 192.3018460649819
# metric: 262.88780877020525
# metric: 179.6941846582688
# metric: 193.93297811357408
# metric: 193.93297811357408
# metric: 186.11824198610947
# metric: 186.11824198610947
# metric: 207.91825316695983
# metric: 207.91825316695983
# metric: 210.19038988498022
# metric: 210.19038988498022
# metric: 189.2353032602532
# metric: 189.2353032602532
# metric: 181.2181006411887
# metric: 181.2181006411887
# metric: 164.19500601419034
# metric: 171.6682847820179
# metric: 258.0310058888272
# metric: 248.63628053846043
# metric: 185.39147768977946
# metric: 209.8523290316312
# metric: nan
# metric: 239.87496743095141
# metric: 201.46960068456977
# metric: 211.42374511865975
# metric: 166.58331248957683
# metric: 198.46914117816905
# metric: 198.46914117816905
# metric: 189.57847979135184
# metric: 189.57847979135184
# metric: 210.42813500100218
# metric: 274.44489428663087
# metric: 285.20168302448707
# metric: 236.3683565962246
# metric: 196.21416870348583
# metric: 178.38161340227865
# metric: 196.21416870348583
# metric: 263.47675419285093
# metric: 225.17992805754247
# metric: 173.65483005087995
# metric: 220.86194783167153
# metric: 223.22634253152114
# metric: 223.22634253152114
# metric: 253.19952606590715
# metric: 194.80759738778156
# metric: 197.40820651634522
# metric: 170.70442290696514
# metric: 178.8295277631745
# metric: 192.17179813906097
# metric: 173.52233285660955
# metric: 173.52233285660955
# metric: 237.1117879819559
# metric: 199.44924166313595
# metric: 177.36967046256808
# metric: 195.7549488518745
# metric: 178.52170736355845
# metric: 178.52170736355845
# metric: 161.4930339054908
# metric: 219.33991884743642
# metric: 520.9222590751906
# metric: 179.72200755611428
# metric: 178.54971296532514
# metric: 205.23157651784484
# metric: 236.7488120350343
# metric: 177.76388834631177
# metric: 209.93332274796205
# metric: 183.0901417335188
# metric: 245.7234217570641
# metric: 173.60875553957524
# metric: 223.29352879114074
# metric: 199.8999749874922
# metric: 188.33480825381164
# metric: 235.902522241709
# metric: 195.12047560417642
# metric: 199.73983077994234
# metric: 205.03658210182886
# metric: 260.5379051117131
# metric: 171.55174146594956
# metric: 296.76590100616346
# metric: 205.91260281974002
# metric: 252.86359959472222
# metric: 200.0999750124922
# metric: 200.0999750124922
# metric: 230.86359609085187
# metric: 217.34764779035453
# metric: 217.34764779035453
# metric: 216.88706738761533
# metric: 192.76929216034384
# metric: 231.66786570433112
# metric: 184.52642087245934
# metric: 219.7498577929005
# metric: 181.08009277664954
# metric: 209.59484726490774
# metric: 196.01020381602586
# metric: 192.3018460649819
# metric: 217.30163368000711
# metric: 269.462427807663
# metric: 269.462427807663
# metric: 161.4930339054908
# metric: 164.43843832875572
# metric: 166.4632091484482
# metric: 200.44949488586894
# metric: 171.26003620226174
# metric: 162.5423021862309
# metric: 233.73061416938947
# metric: 188.86503117305756
# metric: 213.7054047047009
# metric: 187.8776197422141
# metric: 325.08152823561045
# metric: 255.61298871536243
# metric: 173.81024135533556
# metric: 214.2708566277738
# metric: 179.6719232378838
# metric: 160.63000964950479
# metric: 244.20892694576094
# metric: 200.48441335924346
# metric: 168.6238417306402
# metric: 200.89798406156294
# metric: 172.5977983637103
# metric: 174.35595774162695
# metric: 265.16032885784404
# metric: 179.7498261473429
# metric: 263.8749703931769
# metric: 211.44739298463816
# metric: 290.08619408720574
# metric: 234.00854685246006
# metric: nan
# metric: 180.36074961032958
# metric: 168.7305544351704
# metric: 237.31413780051116
# metric: 216.00462958001617
# metric: 315.8322339470751
# metric: 278.91217255616505
# metric: 282.22331583340167
# metric: 256.61254840712684
# metric: 199.2234925906079
# metric: 241.68160873347398
# metric: 180.16658957753515
# metric: 242.42524621004307
# metric: 201.24611797498108
# metric: 163.0950643030009
# metric: 167.33200530681512
# metric: 161.7096162879623
# metric: 243.98770460824454
# metric: 181.3560034848585
# metric: 178.5777141750896
# metric: 169.52875862224676
# metric: 265.81948762270986
# metric: 224.4994432064365
# metric: 182.75666882497066
# metric: 205.01219475923864
# metric: 289.775775385038
# metric: 192.45778757951052
# metric: 212.88494545176275
# metric: 231.12767034693184
# metric: 165.83123951777
# metric: 192.76929216034384
# metric: 166.4932431061393
# metric: 219.76350925483513
# metric: 167.27223320085136
# metric: 169.52875862224676
# metric: 198.31792657246092
# metric: 220.44046815410277
# metric: 182.51027368342858
# metric: 184.0108692441835
# metric: 194.44793647657977
# metric: 178.07301873108122
# metric: 167.69019053003666
# metric: 298.496231131986
# metric: 380.8411742445924
# metric: 207.24381776062705
# metric: 200.424549394529
# metric: 181.71406109599775
# metric: nan
# metric: 264.5562322078238
# metric: 426.462190586692
# metric: 207.17142660125697
# metric: 313.36879231984796
# metric: 209.4755355644186
# metric: 207.24381776062705
# metric: 214.49941724862563
# metric: 255.91014047903613
# metric: 199.5745474753732
# metric: 238.64199127563447
# metric: 179.13681921927719
# metric: 178.60571099491753
# metric: 254.55844122715712
# metric: 184.60769214742922
# metric: 233.32380932943812
# metric: 200.922870773837
# metric: 196.3415391607186
# metric: 253.31798199101462
# metric: 202.16330032921405
# metric: 165.8613879117138
# metric: 167.80941570722425
# metric: 189.1824516174796
# metric: 199.97499843730466
# metric: 160.90369790654285
# metric: 189.93683160461532
# metric: 271.12727638509557
# metric: 272.54357449773056
# metric: 186.70832868407345
# metric: 298.3454373708437
# metric: 241.31307465614043
# metric: 239.1150350772615
# metric: 162.63455967290594
# metric: 521.4115457102959
# metric: 170.8215443086732
# metric: 202.1385663350762
# metric: 169.11534525287763
# metric: 217.62812318264383
# metric: 178.21896644296868
# metric: 218.3162843216236
# metric: 298.767468108561
# metric: 188.30294740125552
# metric: 213.9579397919133
# metric: 173.81024135533556
# metric: 258.9980694908748
# metric: 224.1428116179504
# metric: 183.52111595127138
# metric: 191.54633904097463
# metric: 237.97058641773356
# metric: 195.39703170723962
# metric: 204.132310034448
# metric: 263.60955976595386
# metric: 216.078689370331
# metric: 178.4936973677222
# metric: 184.36377084449103
# metric: 245.49949083450255
# metric: 258.37956575549856
# metric: nan
# metric: 266.1991735524361
# metric: 266.1991735524361
# metric: 184.66726835040367
# metric: 184.66726835040367
# metric: 254.04723970159566
# metric: 232.335963638865
# metric: 207.62947767597933
# metric: 232.335963638865
# metric: 194.80759738778156
# metric: 279.2668974296811
# metric: 216.86401268998046
# metric: 174.55658108475888
# metric: 243.20773014030618
# metric: 216.95621678117453
# metric: 193.77822375076101
# metric: 260.4611295375953
# metric: 195.39703170723962
# metric: 279.2668974296811
# metric: 182.56505689753448
# metric: 304.0723598093059
# metric: 269.3325082495613
# metric: 185.41844568434934
# metric: 184.55351527402559
# metric: 276.3801729502317
# metric: 189.9105052386518
# metric: 213.65860619221496
# metric: 219.84085152673512
# metric: 198.31792657246092
# metric: 166.0421633200435
# metric: 304.8770243885229
# metric: 221.55811878601966
# metric: 216.14347087062333
# metric: 292.36620871776546
# metric: 255.92186307543167
# metric: 208.94018282752603
# metric: 190.30501832584446
# metric: 235.87708663623943
# metric: 257.82552239838475
# metric: 268.0111937960801
# metric: 240.12496746485985
# metric: 235.28705871764387
# metric: 184.39088914585776
# metric: 189.36736783300339
# metric: 193.90719429665316
# metric: 184.82424083436675
# metric: 205.13410247932936
# metric: 181.6314950662467
# metric: 202.3116407921205
# metric: 272.1580423210014
# metric: 394.8290769434288
# metric: 249.81993515330197
# metric: 184.03803954617644
# metric: 183.0027322200409
# metric: 251.91268328530026
# metric: 188.04254837669055
# metric: nan
# metric: 231.01947969814148
# metric: 225.36636838712204
# metric: 197.16997743064232
# metric: 209.69501663129716
# metric: 225.9867252738532
# metric: 213.2791597882925
# metric: 167.95237420173612
# metric: 269.12822222873615
# metric: 241.39179770655008
# metric: 236.07202290826416
# metric: 248.21361767638777
# metric: 294.66930617219026
# metric: 225.41073621280776
# metric: 186.46715528478467
# metric: 195.52493447128424
# metric: 194.6278500112458
# metric: 261.99236630100506
# metric: 194.7819293466414
# metric: 198.31792657246092
# metric: 234.66998103720042
# metric: 216.078689370331
# metric: 175.64168070250295
# metric: 230.73794659743334
# metric: 210.52315787105226
# metric: 226.87000683210638
# metric: 163.18700928689145
# metric: 183.60283222216373
# metric: 209.3800372528384
# metric: 195.52493447128424
# metric: 189.63122105813693
# metric: 172.74258305351347
# metric: 235.74986744428935
# metric: 181.54338324488722
# metric: 206.13102629153138
# metric: 201.81674856165927
# metric: 237.54999473794985
# metric: 172.30786401090347
# metric: 194.07215153133126
# metric: nan
# metric: 225.3441811984503
# metric: 200.64894716892985
# metric: 331.028699662129
# metric: 172.5977983637103
# metric: 177.90446874657195
# metric: 186.84217939212763
# metric: 243.19539469323837
# metric: 208.5281755542881
# metric: nan
# metric: 242.79621084357967
# metric: 209.6425529323663
# metric: 168.4695818241382
# metric: 191.33739833080202
# metric: 231.66786570433112
# metric: 262.58332011001767
# metric: 240.89001639752527
# metric: 224.966664197165
# metric: 166.0421633200435
# metric: 197.3068675946177
# metric: 220.02272609891915
# metric: 178.46568297574746
# metric: 172.30786401090347
# metric: 205.52858681944952
# metric: 188.89679722006935
# metric: 177.31892172015935
# metric: 184.7971861257633
# metric: 244.60171708309818
# metric: 208.71032557111303
# metric: 172.97398648351722
# metric: nan
# metric: 246.0894146443524
# metric: 205.2802961806125
# metric: 170.8215443086732
# metric: 228.9978165834775
# metric: 264.9528259898354
# metric: 302.60535355475787
# metric: 172.53985046939155
# metric: 204.74374227311563
# metric: 161.33815419794539
# metric: 178.5777141750896
# metric: 169.14490828872147
# metric: 207.09901013766338
# metric: 174.78558292948534
# metric: 244.43813123160632
# metric: 264.6696053573209
# metric: 338.3637096380166
# metric: 246.5968369626829
# metric: 303.9572338339721
# metric: 173.81024135533556
# metric: 281.0871750898643
# metric: 365.4449342924321
# metric: 236.9599122214557
# metric: 187.5633226406485
# metric: 195.10509988208918
# metric: 167.24831837719626
# metric: 181.030384190058
# metric: 234.2007685726074
# metric: 201.65812654093563
# metric: 186.60653793476797
# metric: 217.78888860545663
# metric: 184.46137807140008
# metric: 163.0521389004143
# metric: 260.4611295375953
# metric: 210.99763031844694
# metric: 203.78910667648555
# metric: 235.38054295119636
# metric: 186.2364089000859
# metric: 272.6903005242394
# metric: 198.54470529329157
# metric: 245.31612258471722
# metric: 209.52326839756964
# metric: 197.86358937409378
# metric: 272.1580423210014
# metric: 189.34096228761487
# metric: 248.2498741187999
# metric: 286.5100347282796
# metric: 230.20425712831639
# metric: 249.46743274423616
# metric: 260.1768629221284
# metric: 178.69527134202517
# metric: 171.73234989366446
# metric: 171.7905701719393
# metric: 205.8203099793604
# metric: 273.9817512171203
# metric: 164.15236824365343
# metric: 199.19839356781972
# metric: 235.03191272676142
# metric: 203.42074623793906
# metric: 248.91765706755317
# metric: 181.6865432551349
# metric: 213.60243444305593
# metric: 187.49933333214815
# metric: 188.313568284391
# metric: 232.83041038489796
# metric: 261.5148179358103
# metric: 220.9298531208492
# metric: 170.14699527173556
# metric: 221.92341021172146
# metric: 198.31792657246092
# metric: 231.59447316376097
# metric: 233.62362894193728
# metric: 183.43936327844142
# metric: 248.1330288373557
# metric: 211.83012061555362
# metric: 186.52613757862463
# metric: 217.62812318264383
# metric: 174.04597093871493
# metric: 181.24568960391858
# metric: 288.47876871617433
# metric: 330.242335263061
# metric: 208.39385787493833
# metric: 186.5851012272952
# metric: 216.21748310439654
# metric: 186.35986692418516
# metric: 214.4527920079382
# metric: 288.2186669874108
# metric: 247.1032172999777
# metric: 240.43710196223876
# metric: 195.47378340841516
# metric: 235.8643678048891
# metric: 172.08718720462602
# metric: 196.80955261368794
# metric: 205.01219475923864
# metric: 169.61721610732798
# metric: 234.64867355261143
# metric: 192.89893727027115
# metric: 183.05736805712027
# metric: 219.3809472128334
# metric: 173.57419162997707
# metric: 260.2498799231231
# metric: 210.0047618507733
# metric: 173.78722622793657
# metric: 210.95497149865892
# metric: 211.35278564523344
# metric: 169.61721610732798
# metric: 172.45289211839852
# metric: 247.85076154815422
# metric: 186.03763060198332
# metric: 211.64120581777075
# metric: 183.8912722235615
# metric: 172.19175357722565
# metric: 162.14191315017842
# metric: 202.0148509392317
# metric: 174.04022523543227
# metric: 180.38846969803808
# metric: 220.06817125609055
# metric: 173.69513522260777
# metric: 218.6778452427223
# metric: 272.6903005242394
# metric: 212.64994709616084
# metric: 215.89349225949354
# metric: 177.45421944828473
# metric: 198.7108451997525
# metric: 184.38004230393267
# metric: 184.38004230393267
# metric: 184.38004230393267
# metric: 184.38004230393267
# metric: 184.38004230393267
# metric: 179.55500549970753
# metric: 175.5562587890275
# metric: 211.84900282984577
# metric: 203.00246303924493
# metric: 192.53571097331528
# metric: 164.8939052845799
# metric: 268.5702887513807
# metric: 239.22792479140057
# metric: 249.77990311472217
# metric: 189.86837546047525
# metric: 166.0421633200435
# metric: 173.81024135533556
# metric: 168.0773631397161
# metric: 173.81024135533556
# metric: 184.97567407634983
# metric: 217.3706511928416
# metric: 173.81024135533556
# metric: 227.72790781983662
# metric: 184.03803954617644
# metric: 161.4930339054908
# metric: 213.5790251873999
# metric: 195.64253116334393
# metric: 220.85289221561035
# metric: nan
# metric: 186.06450494385004
# metric: 174.38463235044537
# metric: 241.78502848604998
# metric: 185.9569842732453
# metric: 230.8895840006647
# metric: 185.3375299285064
# metric: 180.58239116813135
# metric: 251.6624723712298
# metric: 206.3734479045209
# metric: 225.58368735349637
# metric: 190.0473625178734
# metric: 225.58368735349637
# metric: 190.0473625178734
# metric: 225.58368735349637
# metric: 190.0473625178734
# metric: 241.80157154162583
# metric: 187.05079524022347
# metric: 221.76564206386885
# metric: 190.46259475288053
# metric: 190.9450182644208
# metric: 250.13196517038762
# metric: 191.47323572760763
# metric: 178.26945896591485
# metric: 178.88543819998318
# metric: 228.69193252058542
# metric: 233.9059640111812
# metric: 201.49441679609885
# metric: 222.84523777725204
# metric: 241.82638400306945
# metric: 172.80624988697602
# metric: 183.79880304289253
# metric: 192.6395598001615
# metric: 177.08754896942924
# metric: 228.58258901324922
# metric: 238.64199127563447
# metric: 194.42222095223582
# metric: 181.93405398660252
# metric: 192.89893727027115
# metric: 208.23064135712593
# metric: 207.06520712084878
# metric: 179.48816116947657
# metric: 179.43243853885505
# metric: 241.70229622409465
# metric: 181.57643018850217
# metric: 246.35746386095144
# metric: 175.07712586171843
# metric: 242.77561656805653
# metric: 177.45421944828473
# metric: 186.284728305892
# metric: 237.74355932390682
# metric: 214.66718426438635
# metric: 194.65867563507155
# metric: 211.2581359380036
# metric: 211.2581359380036
# metric: 251.4159899449516
# metric: 251.4159899449516
# metric: 202.65734627691145
# metric: 284.41167345944154
# metric: 179.68305429282975
# metric: 185.68791021496256
# metric: 182.42806801586207
# metric: 193.33908037435162
# metric: 175.1856158478772
# metric: 174.22399375516565
# metric: 229.0633100258529
# metric: 205.71825392998065
# metric: 217.41665069630707
# metric: 176.98022488402484
# metric: 198.95225557907102
# metric: 234.8659191964641
# metric: 238.34848436690342
# metric: 211.1539722572133
# metric: 170.8098357823694
# metric: 170.8098357823694
# metric: 241.5367466867102
# metric: 206.54297373670207
# metric: 234.54210709380095
# metric: 191.57244060668017
# metric: 248.1330288373557
# metric: 199.19839356781972
# metric: 171.87204542915057
# metric: 260.5954719483821
# metric: 222.37355957937086
# metric: 182.04395073717774
# metric: 220.38602496528677
# metric: 184.3474979488466
# metric: 240.07915361396957
# metric: 198.86678958539056
# metric: 172.2440129583609
# metric: 210.8791122894821
# metric: 183.27574853209575
# metric: 198.44394674567425
# metric: 222.44100341438852
# metric: 218.44907873461037
# metric: 215.46229368499723
# metric: 188.79618640216228
# metric: 228.97598127314578
# metric: 181.85158784019455
# metric: nan
# metric: 227.18274582370907
# metric: 188.02127539190877
# metric: 199.71479664761947
# metric: 186.05913038601466
# metric: 211.84900282984577
# metric: 171.0847743079436
# metric: 185.1215816699933
# metric: 251.2767398706056
# metric: 181.38357147217053
# metric: 190.57806799314554
# metric: 210.99763031844694
# metric: 170.7629936490925
# metric: 237.92856070678022
# metric: 213.65860619221496
# metric: 179.55500549970753
# metric: 209.18890983988612
# metric: 205.2802961806125
# metric: 237.1497417245062
# metric: 226.03097132915215
# metric: 241.92974186734463
# metric: 204.03431084011336
# metric: 214.21951358361358
# metric: 175.3111519556015
# metric: 170.54031781370645
# metric: 221.67543842293398
# metric: 224.94443758403986
# metric: 193.95360269920226
# metric: 207.8605301638577
# metric: 202.69681793259608
# metric: 200.14994379214798
# metric: 205.03658210182886
# metric: 181.41113527013715
# metric: 201.88115315699977
# metric: 207.40298937093456
# metric: 180.61007723823164
# metric: 174.12639087743133
# metric: 184.61852561430555
# metric: 193.30804432304416
# metric: 215.42516101885593
# metric: 177.56125703542426
# metric: 176.20442673213407
# metric: 205.52372125864207
# metric: 183.05736805712027
# metric: 180.6045403637461
# metric: 206.59138413786766
# metric: 175.4821928287882
# metric: 198.15145722401337
# metric: 175.82377541163197
# metric: 198.15145722401337
# metric: 187.68057970924963
# metric: 195.67830743339948
# metric: 249.65976848503246
# metric: 200.30976012166755
# metric: 232.81752511355324
# metric: 229.71721746530014
# metric: 296.29377313740497
# metric: 216.6333307688362
# metric: 161.7096162879623
# metric: 161.7096162879623
# metric: 171.54591222177228
# metric: 207.8605301638577
# metric: 195.13585011473418
# metric: 195.72429588581997
# metric: 170.04117148502596
# metric: 186.13973245924686
# metric: 251.91268328530026
# metric: 201.9108714259834
# metric: 174.2067736914957
# metric: 243.96311196572321
# metric: 211.69789795838787
# metric: 184.99729727755485
# metric: 245.81293700698504
# metric: 264.2763704911962
# metric: 174.71691389215871
# metric: 239.08575867248973
# metric: 199.1080108885627
# metric: 173.70089234082823
# metric: 262.52618916976644
# metric: 247.51161588903258
# metric: 207.03139858485235
# metric: 205.54804791094466
# metric: 172.8293956478469
# metric: 255.0098037331114
# metric: 229.21605528409216
# metric: 178.4152459853137
# metric: nan
# metric: 212.71107164414363
# metric: 187.7391807801451
# metric: 205.07071950914883
# metric: 186.25251676151922
# metric: 211.92923347193044
# metric: 183.90758548792923
# metric: 183.90758548792923
# metric: 187.26985876002576
# metric: 274.64522570035695
# metric: 222.77791632026725
# metric: 194.5816024191393
# metric: 176.42562172201633
# metric: 198.66051444612742
# metric: 162.51153805191802
# metric: 215.81010170981338
# metric: 165.83726963502505
# metric: 213.78961621182634
# metric: 182.0109886792553
# metric: nan
# metric: 167.86899654194636
# metric: 209.026314132934
# metric: 165.03332996701
# metric: 263.59438537267823
# metric: 209.53281365934072
# metric: 182.55957931590441
# metric: 200.3696583817021
# metric: 203.32240407785858
# metric: 195.41750177504574
# metric: 182.4828759089466
# metric: 174.13213373757299
# metric: 198.4187491140895
# metric: 230.67292862405853
# metric: 250.6192331007339
# metric: 198.020200989697
# metric: 183.3303030052588
# metric: 174.49928366615148
# metric: 226.01327394646538
# metric: 187.3552774810467
# metric: 196.0459129897892
# metric: 201.82665829864993
# metric: 190.87692369692047
# metric: 186.37059853957652
# metric: 180.07220773900676
# metric: 186.3759641155479
# metric: 177.80888616714296
# metric: 179.7386992275175
# metric: 179.14240145761136
# metric: 283.78160616925123
# metric: 272.1580423210014
# metric: 166.10237806846715
# metric: 231.49082055234933
# metric: 231.49082055234933
# metric: 197.04314248407633
# metric: 187.7285274006058
# metric: 367.76351096866586
# metric: 228.93230440459905
# metric: 274.9727259202265
# metric: 202.41047403728888
# metric: 275.98913022073896
# metric: 187.9627622695517
# metric: 202.18803129760178
# metric: 169.88231220465536
# metric: 185.72021968541821
# metric: 236.22023622035434
# metric: 204.89021450523205
# metric: 188.1488772222678
# metric: 217.35224866561651
# metric: 185.61249957909624
# metric: nan
# metric: 260.6913884270058
# metric: 212.03773249117714
# metric: 200.37464909513878
# metric: 247.85076154815422
# metric: 202.21275924134954
# metric: 228.05701041625534
# metric: 174.1551032843999
# metric: 162.53614982520043
# metric: 210.2997860198626
# metric: 218.00458710770286
# metric: 175.8124000177462
# metric: 175.8124000177462
# metric: 175.8124000177462
# metric: 175.8124000177462
# metric: 251.91268328530026
# metric: 201.14671262538695
# metric: 236.22023622035434
# metric: 203.61728806759018
# metric: 193.75241933973368
# metric: 205.94173933421072
# metric: 300.58276730378276
# metric: 255.91014047903613
# metric: nan
# metric: 226.69803704487606
# metric: 186.46715528478467
# metric: 202.63267258761604
# metric: 243.15838459736486
# metric: 166.0903368652132
# metric: 252.82404948896772
# metric: 179.05306476014312
# metric: 242.404620418011
# metric: 192.19781476385208
# metric: 244.78970566590417
# metric: 191.4210019825411
# metric: 201.24611797498108
# metric: nan
# metric: 266.101484400219
# metric: 233.94443784796422
# metric: 194.6021582614129
# metric: 190.3417978269618
# metric: nan
# metric: 196.5451602049768
# metric: 277.9208520424475
# metric: 225.61028345356956
# metric: 188.20201911775547
# metric: 162.29602582934677
# metric: 196.44337606547083
# metric: 167.92855623746667
# metric: 167.92855623746667
# metric: 175.41379649275024
# metric: 202.70668464557355
# metric: 207.9422996891205
# metric: 193.50968967987106
# metric: 194.67408661658078
# metric: 183.87495751189175
# metric: 191.62463307205576
# metric: 168.25575770237404
# metric: 211.47103820618085
# metric: 210.14280858501917
# metric: 176.52195330892982
# metric: 193.00259065618783
# metric: 191.62463307205576
# metric: 174.18381095842403
# metric: 214.03270778084362
# metric: 168.93785839769603
# metric: 276.0144923731361
# metric: 236.60938273872404
# metric: 253.68484385157896
# metric: 224.285532302019
# metric: 218.43992309099542
# metric: 249.23884127479008
# metric: 266.22546835342405
# metric: 175.3396703544295
# metric: 173.60875553957524
# metric: 319.02351010544663
# metric: 394.57825586314306
# metric: 178.97485856957675
# metric: 265.4731624854008
# metric: 187.46733048720782
# metric: 275.056357861439
# metric: 171.58088471621772
# metric: 204.25474290698858
# metric: 181.9890106572372
# metric: 173.3435894401636
# metric: 351.59635948058394
# metric: 242.86621831782205
# metric: 190.4258385828982
# metric: 204.27432535685926
# metric: 281.86521601644995
# metric: 281.86521601644995
# metric: 217.30163368000711
# metric: 178.4936973677222
# metric: 203.46989949375805
# metric: 203.46989949375805
# metric: 230.13039781828041
# metric: 192.22382786741085
# metric: 195.3202498462461
# metric: 195.3202498462461
# metric: 246.39399343328157
# metric: 201.02238681301145
# metric: 183.52111595127138
# metric: 183.52111595127138
# metric: 201.24611797498108
# metric: 187.08286933869707
# metric: 259.71522866401193
# metric: 196.65197685250968
# metric: 165.74679484080528
# metric: 165.74679484080528
# metric: 319.859344087366
# metric: 211.84900282984577
# metric: 189.52572384771415
# metric: 189.52572384771415
# metric: 284.2147075715822
# metric: 195.69874807979738
# metric: 232.40051635054513
# metric: 183.49386910739008
# metric: 235.32530675641326
# metric: 162.9048802215575
# metric: 217.62812318264383
# metric: 186.92244381026052
# metric: 186.92244381026052
# metric: 221.50395030337495
# metric: 191.45234393968647
# metric: 255.2057993071474
# metric: 165.98192672697832
# metric: 179.6385259347226
# metric: 179.6385259347226
# metric: 217.55459085020476
# metric: 188.33480825381164
# metric: 188.33480825381164
# metric: 177.76388834631177
# metric: 177.76388834631177
# metric: 193.08029417835473
# metric: 191.049731745428
# metric: 191.049731745428
# metric: 195.49936061276517
# metric: 241.047713119208
# metric: 224.73095024940378
# metric: 264.5864697976826
# metric: 182.99180309511135
# metric: 182.99180309511135
# metric: 182.99180309511135
# metric: 224.1428116179504
# metric: 205.5723716845238
# metric: 205.5723716845238
# metric: 204.26942992038727
# metric: 190.69871525524235
# metric: 245.23458157445904
# metric: 190.7354188398159
# metric: 257.056414041743
# metric: 210.8980796498631
# metric: 176.7993212656655
# metric: 176.7993212656655
# metric: 261.6486193351687
# metric: 214.82551058940834
# metric: 209.69024774652732
# metric: 209.69024774652732
# metric: 164.38369748852836
# metric: 183.27574853209575
# metric: 212.03773249117714
# metric: 221.96396103872357
# metric: 170.7629936490925
# metric: 212.60291625469299
# metric: 250.89838580588756
# metric: 180.36074961032958
# metric: 180.36074961032958
# metric: 176.6069081321566
# metric: 193.08029417835473
# metric: 288.0624932197873
# metric: 190.0526242912736
# metric: 222.08106627986098
# metric: 164.28633540255257
# metric: 175.35677916750183
# metric: 202.28692493584452
# metric: 189.63122105813693
# metric: nan
# metric: 203.40108160971022
# metric: nan
# metric: 236.6389655149802
# metric: 236.6389655149802
# metric: 171.26003620226174
# metric: 171.26003620226174
# metric: 163.55427233796127
# metric: 163.55427233796127
# metric: 174.9857137025763
# metric: 272.0845456838738
# metric: 202.36106344848062
# metric: 200.174923504419
# metric: 211.65538027652403
# metric: 283.1218818812845
# metric: 211.65538027652403
# metric: 237.4405188673576
# metric: 210.23796041628637
# metric: 589.1349590713489
# metric: 197.10403344427024
# metric: 210.07141642784245
# metric: 210.07141642784245
# metric: 210.07141642784245
# metric: 210.07141642784245
# metric: 199.07285098676815
# metric: 199.07285098676815
# metric: 206.56718035544756
# metric: 349.4424129953317
# metric: 247.62875438849989
# metric: 190.2104098097683
# metric: 169.73508771023157
# metric: 300.5328601001894
# metric: 170.8215443086732
# Результат на основе расстояний: nan

# %% [markdown]
# Применим метод замены пропусков для номинальных признаков (на основе моды)

# %%
category_df = df.select_dtypes(include=['category'])

for column in category_df.columns:
    if (category_df[column].isnull().sum() > 0):
        category_df[column] = category_df[column].fillna(category_df[column].mode())
        print(column)
        print(category_df[column].mode())
        print('-----------------------------------------------')
# Out:
# name
# 0    Crabominable
# 1         Noctowl
# 2       Toxicroak
# Name: name, dtype: category
# Categories (1069, object): ['Abomasnow', 'Abra', 'Absol', 'Accelgor', ..., 'Zweilous', 'Zygarde 10% Forme', 'Zygarde 50% Forme', 'Zygarde Complete Forme']
# -----------------------------------------------
# type1
# 0    Water
# Name: type1, dtype: category
# Categories (20, object): ['Blastoise', 'Bug', 'Dark', 'Dragon', ..., 'Psychic', 'Rock', 'Steel', 'Water']
# -----------------------------------------------
# type2
# 0    Flying
# Name: type2, dtype: category
# Categories (18, object): ['Bug', 'Dark', 'Dragon', 'Electric', ..., 'Psychic', 'Rock', 'Steel', 'Water']
# -----------------------------------------------

# %% [markdown]
# Замену пропусков на основе моды в этом наборе данных лучше не использовать, так как у всех покемонов своё уникальное имя и свои типы, придуманные авторами.
# Типы можно примерно заполнить на основе характеристик покемонов, например у редкого type2 Dragon значение attack в среднем больше, чем у Flying, но для точных замен придется делать множество вычислений для разных типов.

# %% [markdown]
# **Применим поиск выбросов в числовых признаках**

# %% [markdown]
# На основе простейшего метода из алгоритма 2 (с учетом нормальности)

# %%
float_df = df.select_dtypes(include=['float64'])

total_df = float_df['total']

# normalized_data = (total_df - total_df.min()) / (total_df.max() - total_df.min())

normalized_data = (total_df - total_df.mean()) / total_df.std()

lower_bound = normalized_data.mean() - (3 * normalized_data.std())
upper_bound = normalized_data.mean() + (3 * normalized_data.std())

anomalies = total_df.loc[(normalized_data < lower_bound) | (normalized_data > upper_bound)]

print(anomalies)
# Out:
# 1057    1125.0
# Name: total, dtype: float64

# %% [markdown]
# На основе методов без использования среднего и СКО

# %%
float_df = df.select_dtypes(include=['float64'])

total_df = float_df['total']

q1 = total_df.quantile(0.25)
q3 = total_df.quantile(0.75)

lower_bound = q1 - 1.5 * (q3 - q1)
upper_bound = q1 + 1.5 * (q3 - q1)

anomalies = total_df.loc[(total_df < lower_bound) | (total_df > upper_bound)]
print(anomalies)
# Out:
# 3        625.0
# 8        634.0
# 9        634.0
# 14       630.0
# 176      640.0
#          ...
# 1055     720.0
# 1056     690.0
# 1057    1125.0
# 1070     680.0
# 1071     680.0
# Name: total, Length: 62, dtype: float64

# %% [markdown]
# Метод без использования среднего и СКО оказался более точным, чем на основе простейшего метода

# %% [markdown]
# На основе критерия Шовене

# %%
from scipy.special import erfc
import scipy.stats as st

def chauvenet(y: np.array, mean=None, stdv=None) -> np.array:
    # based on https://github.com/msproteomicstools/msproteomicstools/blob/master/msproteomicstoolslib/math/chauvenet.py
    '''
        Returns: np.array[bool]. if false, then outlier
    '''
    if mean is None:
        mean = y.mean()    # Mean of incoming array y
    if stdv is None:
        stdv = y.std()      # Its standard deviation

    abs_deviation = np.abs(y - mean) / stdv
    d = erfc(abs_deviation)
    # Calculate the maximum absolute deviation that is still acceptable according to Chauvenet's criterion
    threshold = 1 / (2 * y.size - 1)

    # Determine which data points are outliers
    is_outlier = d > threshold

    # Return the indices of the outliers
    return is_outlier

float_df = df.select_dtypes(include=['float64'])

total_df = float_df['total']


mean = total_df.mean()
stdv = total_df.std()

def iterate(sample: np.array, repeat: bool = True) -> np.array:
    test_result = chauvenet(sample, mean, stdv)
    repeat = np.any(test_result == False)
    
    print('sample: ', sample)
    print('test_result: ', test_result)
    print('-----')
    
    if repeat:
        return iterate(sample[test_result], repeat)
    
    return sample
    
print(iterate(sample=total_df))
# Out:
# sample:  0       318.0
# 1       405.0
# 2       525.0
# 3       625.0
# 4       525.0
#         ...
# 1067    580.0
# 1068    580.0
# 1069    500.0
# 1070    680.0
# 1071    680.0
# Name: total, Length: 1072, dtype: float64
# test_result:  0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1067    True
# 1068    True
# 1069    True
# 1070    True
# 1071    True
# Name: total, Length: 1072, dtype: bool
# -----
# sample:  0       318.0
# 1       405.0
# 2       525.0
# 3       625.0
# 4       525.0
#         ...
# 1067    580.0
# 1068    580.0
# 1069    500.0
# 1070    680.0
# 1071    680.0
# Name: total, Length: 1059, dtype: float64
# test_result:  0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1067    True
# 1068    True
# 1069    True
# 1070    True
# 1071    True
# Name: total, Length: 1059, dtype: bool
# -----
# 0       318.0
# 1       405.0
# 2       525.0
# 3       625.0
# 4       525.0
#         ...
# 1067    580.0
# 1068    580.0
# 1069    500.0
# 1070    680.0
# 1071    680.0
# Name: total, Length: 1059, dtype: float64

# %% [markdown]
# Провести поиск аномалий числовых переменных нескольких признаков (???)

# %%
from scipy.spatial.distance import pdist, squareform

float_df = df.select_dtypes(include=['float64'])

columns = ['total', 'hp', 'attack']
new_df = float_df[columns].dropna()
new_df = (new_df - new_df.mean()) / new_df.std()

dist = pdist(new_df, 'euclidean')
dist_matrix = squareform(dist)
bound = np.percentile(dist, 99)

anomalies = []
for i in range(len(dist_matrix)):
    for j in range(i+1, len(dist_matrix)):
        if dist_matrix[i][j] > bound:
            anomalies.append((i, j, dist_matrix[i][j]))

            
print(len(anomalies))
# for anomaly in anomalies:
#     print('Расстояние', round(anomaly[2], 2), 'между объектами', anomaly[0], 'и', anomaly[1])
# Out:
# 5560

# %% [markdown]
# **Тесты на статистическую значимость**

# %% [markdown]
# Выбрать в качестве X и Y числовые переменные

# %%
from scipy.stats import shapiro, ttest_ind

df = pd.read_csv('pokemon.csv')

x = df['hp']
y = df['attack']

x = (x - x.mean()) / x.std()
y = (y - y.mean()) / y.std()

_, p_value_x = shapiro(x)
_, p_value_y = shapiro(y)

print('p-value x:', p_value_x)
print('p-value y:', p_value_y)

_, p_value = ttest_ind(x, y)

print('p-value:', p_value)
# Out:
# p-value x: 3.771548301944733e-26
# p-value y: 1.2264919080351433e-09
# p-value: 0.9999999999999969

# %% [markdown]
# Обычно установлен порог P-value в 0.05 или 0.01, что означает, что если P-value меньше этого порога, мы можем считать результаты статистически значимыми и отвергнуть нулевую гипотезу

# %% [markdown]
# Выбрать в качестве X и Y числовую и номинальную переменную соответственно

# %%
import scipy.stats as stats

df['x'] = (df['hp'] - df['hp'].mean()) / df['hp'].std()
sns.histplot(df['x'])
stats.normaltest(df['x'])

#ANOVA
groups = []
for group in df['type1'].unique():
    groups.append(df.loc[df['type1'] == group, 'x'])
    
result = stats.f_oneway(*groups)
print(result)
# Out:
# F_onewayResult(statistic=2.949725349286105, pvalue=2.2906512382480154e-05)

# %% [markdown]
# Значение тестовой статистики равно 2.95, а p-value 2.29e-5. Тестовая статистика говорит о том, что есть статистически значимые различия. Значение p-value позволяет отклонить нулевую гипотезу и значит есть статистически значимые различия между двумя выборками.

# %% [markdown]
# Выбрать в качестве X и Y номинальные переменные

# %%
#Частота каждой категории
crosstab = pd.crosstab(df['type1'], df['type2'])
# Критерий хи-квадрат
chi2, p_val, dof, expected_freq = stats.chi2_contingency(crosstab)

print("Chi-square statistic: ", chi2)
print("P-value: ", p_val)
print("Degrees of freedom: ", dof)
print("Expected frequencies:\n", expected_freq)
# Out:
# Chi-square statistic:  728.0653279219121
# P-value:  2.0489783669885528e-36
# Degrees of freedom:  306
# Expected frequencies:
#  [[ 0.0174216   0.04878049  0.06097561  0.01916376  0.07665505  0.05574913
#    0.03135889  0.19860627  0.04529617  0.05052265  0.06794425  0.03310105
#    0.01916376  0.07142857  0.07491289  0.02787456  0.06271777  0.03832753]
#  [ 1.11498258  3.12195122  3.90243902  1.22648084  4.90592334  3.56794425
#    2.00696864 12.71080139  2.8989547   3.23344948  4.34843206  2.1184669
#    1.22648084  4.57142857  4.79442509  1.78397213  4.01393728  2.45296167]
#  [ 0.59233449  1.65853659  2.07317073  0.65156794  2.60627178  1.89547038
#    1.06620209  6.75261324  1.54006969  1.71777003  2.31010453  1.12543554
#    0.65156794  2.42857143  2.54703833  0.94773519  2.13240418  1.30313589]
#  [ 0.48780488  1.36585366  1.70731707  0.53658537  2.14634146  1.56097561
#    0.87804878  5.56097561  1.26829268  1.41463415  1.90243902  0.92682927
#    0.53658537  2.          2.09756098  0.7804878   1.75609756  1.07317073]
#  [ 0.50522648  1.41463415  1.76829268  0.55574913  2.22299652  1.61672474
#    0.90940767  5.75958188  1.31358885  1.46515679  1.97038328  0.95993031
#    0.55574913  2.07142857  2.17247387  0.80836237  1.81881533  1.11149826]
#  [ 0.05226481  0.14634146  0.18292683  0.05749129  0.22996516  0.16724739
#    0.09407666  0.59581882  0.1358885   0.15156794  0.20383275  0.09930314
#    0.05749129  0.21428571  0.22473868  0.08362369  0.18815331  0.11498258]
#  [ 0.26132404  0.73170732  0.91463415  0.28745645  1.14982578  0.83623693
#    0.47038328  2.97909408  0.67944251  0.75783972  1.01916376  0.49651568
#    0.28745645  1.07142857  1.12369338  0.41811847  0.94076655  0.57491289]
#  [ 0.57491289  1.6097561   2.01219512  0.63240418  2.52961672  1.83972125
#    1.03484321  6.55400697  1.49477352  1.66724739  2.24216028  1.09233449
#    0.63240418  2.35714286  2.47212544  0.91986063  2.06968641  1.26480836]
#  [ 0.08710801  0.24390244  0.30487805  0.09581882  0.38327526  0.27874564
#    0.15679443  0.99303136  0.22648084  0.25261324  0.33972125  0.16550523
#    0.09581882  0.35714286  0.37456446  0.13937282  0.31358885  0.19163763]
#  [ 0.48780488  1.36585366  1.70731707  0.53658537  2.14634146  1.56097561
#    0.87804878  5.56097561  1.26829268  1.41463415  1.90243902  0.92682927
#    0.53658537  2.          2.09756098  0.7804878   1.75609756  1.07317073]
#  [ 0.88850174  2.48780488  3.1097561   0.97735192  3.90940767  2.84320557
#    1.59930314 10.12891986  2.31010453  2.57665505  3.46515679  1.68815331
#    0.97735192  3.64285714  3.82055749  1.42160279  3.19860627  1.95470383]
#  [ 0.41811847  1.17073171  1.46341463  0.45993031  1.83972125  1.33797909
#    0.75261324  4.76655052  1.08710801  1.21254355  1.63066202  0.79442509
#    0.45993031  1.71428571  1.79790941  0.66898955  1.50522648  0.91986063]
#  [ 0.33101045  0.92682927  1.15853659  0.3641115   1.45644599  1.05923345
#    0.59581882  3.77351916  0.86062718  0.95993031  1.29094077  0.62891986
#    0.3641115   1.35714286  1.42334495  0.52961672  1.19163763  0.728223  ]
#  [ 0.76655052  2.14634146  2.68292683  0.84320557  3.3728223   2.45296167
#    1.37979094  8.73867596  1.99303136  2.22299652  2.98954704  1.45644599
#    0.84320557  3.14285714  3.29616725  1.22648084  2.75958188  1.68641115]
#  [ 0.43554007  1.2195122   1.52439024  0.47909408  1.91637631  1.39372822
#    0.78397213  4.96515679  1.13240418  1.2630662   1.69860627  0.82752613
#    0.47909408  1.78571429  1.8728223   0.69686411  1.56794425  0.95818815]
#  [ 0.6271777   1.75609756  2.19512195  0.68989547  2.75958188  2.00696864
#    1.12891986  7.14982578  1.63066202  1.81881533  2.44599303  1.19163763
#    0.68989547  2.57142857  2.69686411  1.00348432  2.25783972  1.37979094]
#  [ 0.78397213  2.19512195  2.74390244  0.86236934  3.44947735  2.5087108
#    1.41114983  8.93728223  2.03832753  2.27351916  3.05749129  1.48954704
#    0.86236934  3.21428571  3.37108014  1.2543554   2.82229965  1.72473868]
#  [ 0.45296167  1.26829268  1.58536585  0.49825784  1.99303136  1.44947735
#    0.81533101  5.16376307  1.17770035  1.31358885  1.76655052  0.86062718
#    0.49825784  1.85714286  1.94773519  0.72473868  1.63066202  0.99651568]
#  [ 1.11498258  3.12195122  3.90243902  1.22648084  4.90592334  3.56794425
#    2.00696864 12.71080139  2.8989547   3.23344948  4.34843206  2.1184669
#    1.22648084  4.57142857  4.79442509  1.78397213  4.01393728  2.45296167]]
